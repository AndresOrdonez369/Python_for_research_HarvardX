# %%
import pandas as pd
table=pd.DataFrame(columns=("name","age"))
table.loc[1]="Jorge",22
table.loc[2]="Andres",35
table[table.name=="Jorge"]
# Out:
#     name age
# 1  Jorge  22

# %%
#reindex
x=pd.Series([6,3,8,3], index=["d","a","c","b"])
x.reindex(sorted(x.index))
# Out:
# a    3
# b    3
# c    8
# d    6
# dtype: int64

# %%
#add argument with same index
x=pd.Series([6,3,8,3], index=["d","a","c","b"])
y=pd.Series([7,2,5,1], index=["e","t","c","a"])
x+y
# Out:
# a     4.0
# b     NaN
# c    13.0
# d     NaN
# e     NaN
# t     NaN
# dtype: float64

# %%
data={"name":["andi","Juanis","Sandra","Oswaldo"],
      "age":[12,34,12,12],
      "zip":[1201,12313,1234,1123]}
basic_data=pd.DataFrame(data)
basic_data
# Out:
# 0       andi
# 1     Juanis
# 2     Sandra
# 3    Oswaldo
# Name: name, dtype: object

# %%
import os
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
def sumar(x,y):
    z=x+y
    return z
    
z=2
x=3
y=5
sumar(x,y)
z
# Out:
# 2
