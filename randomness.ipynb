# %%
import matplotlib.pyplot as plt
import numpy as np
import random
y=random.choice([1,2,3,4,5,6])
x=[random.choice([1,2,3,4,5,6]) for i in range(0,1000000)]
list=[]
for i in range(1,100):
  if x[i]== 1:
    list.append(x[i])
plt.hist(x, bins=np.linspace(0.5,6.5,7))
# Out:
# (array([166057., 166748., 166828., 166887., 166553., 166927.]),
#  array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5]),
#  <a list of 6 Patch objects>)

# %%
ys=[]
for k in range(10000000):
  y=0
  for k in range(10):
    x=random.choice([1,2,3,4,5,6]) 
    y+=x
  ys.append(y)
ys
plt.hist(ys);
# Out:
# (array([1.800000e+02, 1.465100e+04, 2.380920e+05, 1.312289e+06,
#         2.354562e+06, 3.467432e+06, 2.032798e+06, 5.269680e+05,
#         5.173100e+04, 1.297000e+03]),
#  array([10. , 14.8, 19.6, 24.4, 29.2, 34. , 38.8, 43.6, 48.4, 53.2, 58. ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.random.random((5,3))
np.random.normal(0,1,(5,3))
# Out:
# array([[-1.30849778, -1.89237716, -0.4752438 ],
#        [-1.1146139 ,  0.44461288, -0.88175344],
#        [ 0.40595164,  1.55233079,  1.35178618],
#        [-1.12489981, -2.57464655,  0.53349686],
#        [-0.10735346,  1.30483283, -0.82805038]])

# %%
x=np.random.randint(1,7,(10,3))
np.sum(x,axis=0)
# Out:
# array([35, 29, 27])

# %%
x=np.random.randint(1,7,(10000000,10))
y=np.sum(x,axis=1)
plt.hist(y)
# Out:
# (array([1.326000e+03, 5.231100e+04, 5.274690e+05, 2.028497e+06,
#         2.752003e+06, 3.072324e+06, 1.314024e+06, 2.374270e+05,
#         1.445900e+04, 1.600000e+02]),
#  array([12. , 16.8, 21.6, 26.4, 31.2, 36. , 40.8, 45.6, 50.4, 55.2, 60. ]),
#  <a list of 10 Patch objects>)

# %%
np.random.random((5,2,3))
np.random.normal(1,2,3)
# Out:
# array([ 3.26624974, -0.42439483,  1.20869785])

# %%
np.sum(np.random.randint(1,7,(100,10)), axis=0)
# Out:
# array([350, 367, 355, 364, 343, 356, 326, 317, 351, 351])

# %%
L1=[1,2,3]
L2=L1
L2[0]=4
L1
# Out:
# [4, 2, 3]
